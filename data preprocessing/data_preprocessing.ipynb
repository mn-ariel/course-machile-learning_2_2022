# %% [markdown]
# # Ejemplo 1
#
# ## Pokemon Dataset

# %%
# Importamos nuestras liberias y sus alias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pk_df = pd.read_csv('https://raw.githubusercontent.com/mn-ariel/course-machile-learning/main/datasets/df_pokemon.csv')

# %%
pk_df.head()
# Out:
#          Name Variation  Type1   Type2  Total  HP  Attack  Defense  Sp.Atk  \
# 0   Bulbasaur       NaN  Grass  Poison    318  45      49       49      65
# 1     Ivysaur       NaN  Grass  Poison    405  60      62       63      80
# 2    Venusaur       NaN  Grass  Poison    525  80      82       83     100
# 3    Venusaur     Mega   Grass  Poison    625  80     100      123     122
# 4  Charmander       NaN   Fire     NaN    309  39      52       43      60
#
#    Sp.Def  Speed
# 0      65     45
# 1      80     60
# 2     100     80
# 3     120     80
# 4      50     65

# %%
pk_df.Name = pk_df.Name.str.replace(".*(?=Mega)","", regex=True)

# %%
pk_df.head()
# Out:
#          Name Variation  Type1   Type2  Total  HP  Attack  Defense  Sp.Atk  \
# 0   Bulbasaur       NaN  Grass  Poison    318  45      49       49      65
# 1     Ivysaur       NaN  Grass  Poison    405  60      62       63      80
# 2    Venusaur       NaN  Grass  Poison    525  80      82       83     100
# 3    Venusaur     Mega   Grass  Poison    625  80     100      123     122
# 4  Charmander       NaN   Fire     NaN    309  39      52       43      60
#
#    Sp.Def  Speed
# 0      65     45
# 1      80     60
# 2     100     80
# 3     120     80
# 4      50     65

# %%
df = pd.DataFrame({"Name": ["VenusaurMega Venusaur","CharmanderMega Charmander","Charmander"]})
df.head()
# Out:
#                         Name
# 0      VenusaurMega Venusaur
# 1  CharmanderMega Charmander
# 2                 Charmander

# %%
df.Name = df.Name.str.replace(".*(?=Mega)","") 
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#               Name
# 0    Mega Venusaur
# 1  Mega Charmander
# 2       Charmander

# %%
pk_df.columns
# Out:
# Index(['Name', 'Variation', 'Type1', 'Type2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp.Atk', 'Sp.Def', 'Speed'],
#       dtype='object')

# %%
pk_df.columns = pk_df.columns.str.replace(".","_", regex=True)

# %%
pk_df.columns = pk_df.columns.str.lower().str.replace(" ","")

# %%
pk_df.columns
# Out:
# Index(['name', 'variation', 'type1', 'type2', 'total', 'hp', 'attack',
#        'defense', 'sp_atk', 'sp_def', 'speed'],
#       dtype='object')

# %%
pk_df.set_index('name')
# Out:
#                   variation   type1   type2  total   hp  attack  defense  \
# name
# Bulbasaur               NaN   Grass  Poison    318   45      49       49
# Ivysaur                 NaN   Grass  Poison    405   60      62       63
# Venusaur                NaN   Grass  Poison    525   80      82       83
# Venusaur              Mega    Grass  Poison    625   80     100      123
# Charmander              NaN    Fire     NaN    309   39      52       43
# ...                     ...     ...     ...    ...  ...     ...      ...
# Basculin     White-Striped    Water     NaN    460   70      92       65
# Basculegion           Male    Water   Ghost    530  120     112       65
# Basculegion         Female    Water   Ghost    530  120      92       65
# Kleavor                 NaN     Bug    Rock    505   70     135       95
# Ursaluna                NaN  Normal  Ground    550  130     140      105
#
#              sp_atk  sp_def  speed
# name
# Bulbasaur        65      65     45
# ...

# %%
pk_df = pk_df.set_index('name')

# %%
pk_df.head(10)
# Out:
#            variation  type1   type2  total  hp  attack  defense  sp_atk  \
# name
# Bulbasaur        NaN  Grass  Poison    318  45      49       49      65
# Ivysaur          NaN  Grass  Poison    405  60      62       63      80
# Venusaur         NaN  Grass  Poison    525  80      82       83     100
# Venusaur       Mega   Grass  Poison    625  80     100      123     122
# Charmander       NaN   Fire     NaN    309  39      52       43      60
# Charmeleon       NaN   Fire     NaN    405  58      64       58      80
# Charizard        NaN   Fire  Flying    534  78      84       78     109
# Charizard     Mega X   Fire  Dragon    634  78     130      111     130
# Charizard     Mega Y   Fire  Flying    634  78     104       78     159
# Squirtle         NaN  Water     NaN    314  44      48       65      50
#
#             sp_def  speed
# name
# Bulbasaur       65     45
# Ivysaur         80     60
# Venusaur       100     80
# Venusaur       120     80
# ...

# %%
pk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1071 entries, Bulbasaur to Ursaluna
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   variation  197 non-null    object
#  1   type1      1071 non-null   object
#  2   type2      579 non-null    object
#  3   total      1071 non-null   int64
#  4   hp         1071 non-null   int64
#  5   attack     1071 non-null   int64
#  6   defense    1071 non-null   int64
#  7   sp_atk     1071 non-null   int64
#  8   sp_def     1071 non-null   int64
#  9   speed      1071 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 92.0+ KB

# %%
pk_df.isnull().any()
# Out:
# variation     True
# type1        False
# type2         True
# total        False
# hp           False
# attack       False
# defense      False
# sp_atk       False
# sp_def       False
# speed        False
# dtype: bool

# %%
pk_df.isna().sum()
# Out:
# variation    874
# type1          0
# type2        492
# total          0
# hp             0
# attack         0
# defense        0
# sp_atk         0
# sp_def         0
# speed          0
# dtype: int64

# %%
pk_df['variation'] = pk_df['variation'].fillna('no_variation')

# %%
pk_df.head(10)
# Out:
#                variation  type1   type2  total  hp  attack  defense  sp_atk  \
# name
# Bulbasaur   no_variation  Grass  Poison    318  45      49       49      65
# Ivysaur     no_variation  Grass  Poison    405  60      62       63      80
# Venusaur    no_variation  Grass  Poison    525  80      82       83     100
# Venusaur           Mega   Grass  Poison    625  80     100      123     122
# Charmander  no_variation   Fire     NaN    309  39      52       43      60
# Charmeleon  no_variation   Fire     NaN    405  58      64       58      80
# Charizard   no_variation   Fire  Flying    534  78      84       78     109
# Charizard         Mega X   Fire  Dragon    634  78     130      111     130
# Charizard         Mega Y   Fire  Flying    634  78     104       78     159
# Squirtle    no_variation  Water     NaN    314  44      48       65      50
#
#             sp_def  speed
# name
# Bulbasaur       65     45
# Ivysaur         80     60
# Venusaur       100     80
# ...

# %%
pk_df.drop('type2',inplace=True,axis=1)

# %%
pk_df.head(10)
# Out:
#                variation  type1  total  hp  attack  defense  sp_atk  sp_def  \
# name
# Bulbasaur   no_variation  Grass    318  45      49       49      65      65
# Ivysaur     no_variation  Grass    405  60      62       63      80      80
# Venusaur    no_variation  Grass    525  80      82       83     100     100
# Venusaur           Mega   Grass    625  80     100      123     122     120
# Charmander  no_variation   Fire    309  39      52       43      60      50
# Charmeleon  no_variation   Fire    405  58      64       58      80      65
# Charizard   no_variation   Fire    534  78      84       78     109      85
# Charizard         Mega X   Fire    634  78     130      111     130      85
# Charizard         Mega Y   Fire    634  78     104       78     159     115
# Squirtle    no_variation  Water    314  44      48       65      50      64
#
#             speed
# name
# Bulbasaur      45
# Ivysaur        60
# Venusaur       80
# Venusaur       80
# Charmander     65
# ...

# %%
pk_df = pk_df.dropna(axis=0)

# %%
pk_df.head(10)
# Out:
#                variation  type1  total  hp  attack  defense  sp_atk  sp_def  \
# name
# Bulbasaur   no_variation  Grass    318  45      49       49      65      65
# Ivysaur     no_variation  Grass    405  60      62       63      80      80
# Venusaur    no_variation  Grass    525  80      82       83     100     100
# Venusaur           Mega   Grass    625  80     100      123     122     120
# Charmander  no_variation   Fire    309  39      52       43      60      50
# Charmeleon  no_variation   Fire    405  58      64       58      80      65
# Charizard   no_variation   Fire    534  78      84       78     109      85
# Charizard         Mega X   Fire    634  78     130      111     130      85
# Charizard         Mega Y   Fire    634  78     104       78     159     115
# Squirtle    no_variation  Water    314  44      48       65      50      64
#
#             speed
# name
# Bulbasaur      45
# Ivysaur        60
# Venusaur       80
# Venusaur       80
# Charmander     65
# ...

# %%
pk_df['type1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Dark', 'Poison',
#        'Electric', 'Ground', 'Ice', 'Fairy', 'Steel', 'Fighting',
#        'Psychic', 'Rock', 'Ghost', 'Dragon', 'Flying', 'Eletric'],
#       dtype=object)

# %%
pk_df['type1'].value_counts()
# Out:
# Psychic     26
# Water       19
# Electric    15
# Ghost       14
# Dragon      13
# Ice         13
# Fire        12
# Dark        11
# Rock        11
# Normal       9
# Poison       9
# Grass        8
# Steel        8
# Fighting     8
# Ground       7
# Bug          7
# Fairy        4
# Flying       2
# Eletric      1
# Name: type1, dtype: int64

# %%
pk_df['type1'].value_counts().keys()
# Out:
# Index(['Psychic', 'Water', 'Electric', 'Ghost', 'Dragon', 'Ice', 'Fire',
#        'Dark', 'Rock', 'Normal', 'Poison', 'Grass', 'Steel', 'Fighting',
#        'Ground', 'Bug', 'Fairy', 'Flying', 'Eletric'],
#       dtype='object')

# %%
pk_df.describe()
# Out:
#              total           hp       attack      defense       sp_atk  \
# count  1071.000000  1071.000000  1071.000000  1071.000000  1071.000000
# mean    441.261438    70.366947    80.945845    74.864613    73.422969
# std     121.610604    26.646330    32.385281    31.170939    32.840700
# min     175.000000     1.000000     5.000000     5.000000    10.000000
# 25%     330.000000    50.000000    56.500000    52.000000    50.000000
# 50%     460.000000    68.000000    80.000000    70.000000    65.000000
# 75%     517.500000    84.000000   100.000000    90.000000    95.000000
# max    1125.000000   255.000000   190.000000   250.000000   194.000000
#
#             sp_def        speed
# count  1071.000000  1071.000000
# mean     72.481793    69.179272
# std      28.012037    30.229644
# min      20.000000     5.000000
# 25%      50.000000    45.000000
# 50%      70.000000    65.000000
# 75%      90.000000    90.000000
# max     250.000000   200.000000

# %%
pk_df.describe().T
# Out:
#          count        mean         std    min    25%    50%    75%     max
# total    197.0  532.010152  127.577747  175.0  466.0  530.0  600.0  1125.0
# hp       197.0   76.974619   27.167364   10.0   60.0   75.0   92.0   255.0
# attack   197.0  101.228426   36.158009   20.0   71.0  100.0  127.0   190.0
# defense  197.0   89.197970   34.327599   20.0   70.0   85.0  107.0   250.0
# sp_atk   197.0   92.456853   41.095265   10.0   60.0   85.0  125.0   194.0
# sp_def   197.0   85.827411   29.538813   20.0   65.0   83.0  105.0   250.0
# speed    197.0   86.324873   33.195095   15.0   60.0   90.0  110.0   180.0

# %%
pk_df.count().sort_values()
# Out:
# variation    197
# type1        197
# total        197
# hp           197
# attack       197
# defense      197
# sp_atk       197
# sp_def       197
# speed        197
# dtype: int64

# %% [markdown]
# ## Histograma
# Un histograma es un gráfico de columnas que muestra datos de frecuencia. La altura representa la cantidad de veces que aparece un valor dentro de ese intervalo.

# %%
def display_dataset_distributions(dataset):
    fig = dataset.hist(xlabelsize=12, ylabelsize=12,figsize=(22,10))
    [x.title.set_size(14) for x in fig.ravel()]
    plt.tight_layout()
    plt.show()

# %%
display_dataset_distributions(pk_df)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))

plt.bar(pk_df['type1'].value_counts().keys(),pk_df['type1'].value_counts())

plt.xlabel('Tipos de Pokemon')
plt.ylabel('Total')
plt.show()

# %%
# Crear el dataset
data = {'C':20, 'C++':15, 'Java':30, 'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (5, 5))
 
# Crear la grafica de barras
plt.bar(courses, values, color ='blue', width = 0.5)
 
plt.xlabel("Cursos ofrecidos")
plt.ylabel("Numero de estudiantes matriculados")
plt.title("Alumnos matriculados en diferentes cursos")
plt.show()

# %% [markdown]
# # Resultado explicado <br>
# Muestra la relacion entre dos columnas <br>
# El número varía de -1 a 1. <br>
# 1 significa que hay una relación de 1 a 1 (una correlación perfecta) <br>
# 0.9 también es una buena relación <br>
# 0.2 significa NO una buena relación <br>

# %%
pk_df.corr()
# Out:
#             total        hp    attack   defense    sp_atk    sp_def     speed
# total    1.000000  0.651307  0.733224  0.627552  0.730430  0.718559  0.556821
# hp       0.651307  1.000000  0.449201  0.302431  0.368151  0.390066  0.184193
# attack   0.733224  0.449201  1.000000  0.459216  0.362515  0.266965  0.367695
# defense  0.627552  0.302431  0.459216  1.000000  0.218902  0.537237 -0.000744
# sp_atk   0.730430  0.368151  0.362515  0.218902  1.000000  0.512009  0.439022
# sp_def   0.718559  0.390066  0.266965  0.537237  0.512009  1.000000  0.224015
# speed    0.556821  0.184193  0.367695 -0.000744  0.439022  0.224015  1.000000

# %%
plt.figure(figsize=(10,8))

sns.heatmap(pk_df.corr(),annot=True)

plt.show()
